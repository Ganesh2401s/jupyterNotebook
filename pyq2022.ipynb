# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

arr1 = np.array([[4, 3, 2], [1, 9, 6]])
arr2 = np.array([[3, 7, 5], [2, 9, 8], [5, 1, 6]])

arr2[1][1]  #np.int64(9)
arr1[:2, -1]  #array([2, 6])
arr1 * 3  #array([[12,  9,  6],[ 3, 27, 18]])
arr1 > 5 # array([[False, False, False], [False, True, True]])
arr2[2] = 4 # array([[3, 7, 5], [2, 9, 8], [4, 4, 4]])
# Out:
# array([[3, 7, 5],
#        [2, 9, 8],
#        [4, 4, 4]])

# %%
dataFrame = {
    "Company_Name" : ["TCS", "Reliance", "L & T", "Wipro"], 
    "Profit" : [350, 200, 800, 150]
}

series = {
    "Company_Name" : "Profit",
    "TCS" : 350, 
    "Reliance" : 200, 
    "L & T" : 800, 
    "Wipro" : 150
}

pdseries = pd.Series(series, index=["Company_Name", "TCS", "Reliance", "L & T", "Wipro"])
pdseries
# Out:
# Company_Name    Profit
# TCS                350
# Reliance           200
# L & T              800
# Wipro              150
# dtype: object

# %%
for i in pdseries.index[1:]:
    if pdseries[i] > 250: 
        print(pdseries[])
# Out:
# 350
# 800

# %%
pdseries[1:][pdseries[1:] > 250]
# Out:
# TCS      350
# L & T    800
# dtype: object

# %%
pdseries.index
# Out:
# Index(['Company_Name', 'TCS', 'Reliance', 'L & T', 'Wipro'], dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

revenue = [581, 684, 739, 563, 856, 716, 589, 820, 792, 695]
expenditure = [631, 545, 435, 532, 688, 540, 485, 679, 709, 535]

plt.scatter(revenue, expenditure, cmap="virdis", c="red")
plt.title("Scatter Plot Comparing Companies Revenue and expenditures")
plt.xlabel("Monthly Revenue in Crores")
plt.ylabel("Monthly Expenditure in Crores")
plt.colorbar()
plt.show()
# Out:
# C:\Users\Ganesh\AppData\Local\Temp\ipykernel_5908\1053679026.py:8: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(revenue, expenditure, cmap="virdis", c="red")

# %%
import numpy as np
import pandas as pd

data = np.arange(20).reshape(5, 4)
df = pd.DataFrame(data, index=["L", "M", "N", "O", "P"], columns= ["Col1", "Col2", "Col3", "Col4"])
df
# Out:
#    Col1  Col2  Col3  Col4
# L     0     1     2     3
# M     4     5     6     7
# N     8     9    10    11
# O    12    13    14    15
# P    16    17    18    19

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dataframe = {
    "Rooms" : [2, 2, 2, 1, 2, 3, 1, 1, 1, 3, 3, 2, 2], 
    "Area" : [1100, 800, 900, 250, 1000, 1200, 400, 250, 375, 900, 1286, 600, 800],
    "Bathroom" : [2, 1, 2, 1, 2, 2, 1, 1, 1, 2, 2, 1, 1],
    "Furnishing_Status" : ["Unfurnished", "Semi-Furnished", "Furnished", "Unfurnished", "Semi-Furnished", "Semi-Furnished", "Unfurnished", "Furnished", "Unfurnished", "Urnnfuished", "Furnished", "Semi-Furnished", "Unfurnished" ], 
    "Rent" : [10000, 16000, 22000, 5000, 23000, 25000, 7000, 6500, 6000, 8500, 35000, 8000, 12000]
}

House_Rent = pd.DataFrame(dataframe)
House_Rent
# Out:
#     Rooms  Area  Bathroom Furnishing_Status   Rent
# 0       2  1100         2       Unfurnished  10000
# 1       2   800         1    Semi-Furnished  16000
# 2       2   900         2         Furnished  22000
# 3       1   250         1       Unfurnished   5000
# 4       2  1000         2    Semi-Furnished  23000
# 5       3  1200         2    Semi-Furnished  25000
# 6       1   400         1       Unfurnished   7000
# 7       1   250         1         Furnished   6500
# 8       1   375         1       Unfurnished   6000
# 9       3   900         2       Urnnfuished   8500
# 10      3  1286         2         Furnished  35000
# 11      2   600         1    Semi-Furnished   8000
# 12      2   800         1       Unfurnished  12000

# %%
max_rent = House_Rent["Rent"].max()
House_Rent[House_Rent["Rent"] == max_rent]
# Out:
#     Rooms  Area  Bathroom Furnishing_Status   Rent
# 10      3  1286         2         Furnished  35000

# %%
total_area = House_Rent["Area"].sum()
total_rent = House_Rent["Rent"].sum()
print(f"Total area is {total_area} and Total rent is {total_rent}.")
# Out:
# Total area is 9861 and Total rent is 184000.

# %%
one_room = House_Rent["Rooms"][House_Rent["Rooms"] == 1].count()
two_room = House_Rent["Rooms"][House_Rent["Rooms"] == 2].count()
three_room = House_Rent["Rooms"][House_Rent["Rooms"] == 3].count()

print(f"The houses with 1, 2, 3 rooms are {one_room}, {two_room}, {three_room} in number respectively.")
# Out:
# The houses with 1, 2, 3 rooms are 4, 6, 3 in number respectively.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
y = House_Rent["Furnishing_Status"]
x = ["Furnished", "Unfurnished", "Semi-Furnished"]
plt.bar(x, y,  width=0.5)
plt.title("House Data")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[85], line 6
#       4 y = House_Rent["Furnishing_Status"]
#       5 x = ["Furnished", "Unfurnished", "Semi-Furnished"]
# ----> 6 plt.bar(x, y,  width=0.5)
#       7 plt.title("House Data")
#       8 plt.show()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\matplotlib\pyplot.py:2981, in bar(x, height, width, bottom, align, data, **kwargs)
#    2970 @_copy_docstring_and_deprecators(Axes.bar)
#    2971 def bar(
#    2972     x: float | ArrayLike,
#    (...)
#    2979     **kwargs,
#    2980 ) -> BarContainer:
# -> 2981     return gca().bar(
#    2982         x,
#    2983         height,
#    2984         width=width,
#    2985         bottom=bottom,
#    2986         align=align,
#    2987         **({"data": data} if data is not None else {}),
#    2988         **kwargs,
#    2989     )
#
# ...
